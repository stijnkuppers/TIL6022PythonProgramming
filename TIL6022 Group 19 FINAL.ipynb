# %% [markdown]
# # TIL6022 Group 19 assignment
#
# ## Group members:
#        - Erik Smit      (4602358)
#        - Pim van Velzen (4594886)
#        - Stijn Küppers  (4726030)
#        - Sven Donders   (4669932)
#
# Instructor: P.K. Krishnakumari
#
# ### Introduction
# This report will investigate the influence of the costs of fossil fuels on the motives for travelling of people in the Netherlands in 2022. Throughout the year 2022 there were some events that possibly changes the human travelling behavior.
#
#
# ### Research objective
# -  	How do the recent fluctuations of fossil fuel costs change the motives for travel of people in the Netherlands in 2022?
#
# #### Subquestions
# - 	How did the costs of fossil fuels change during the year 2022?
# - 	How did the proportion of trips to different destinations change during the year 2022?
# -	How did the prices of fossil fuels influences the amount of traffic jams?
# -	How strong is the correlation between the costs of fossil fuels and the mobility behavior?

# %% [markdown]
# ## Data origin and location
# For answering the questions above, data is needed. The data for fossil fuels and the motives for travel was found in online. Since the outbreak of COVID-19, Google tried to collect mobility reports and give insights into the behavior of people changes during the corona crisis. Combining the behavior of people with the fluctuation of fossil fuel prices, some interesting could result. The institute in the Netherlands which collect all the statistical data is CBS. They can give the day-to-day prices of fossil fuel in the Netherlands. Rijkswaterstaat has the information about traffic jams in the Netherlands.
#
# The data about the mobility of persons:
# https://www.google.com/covid19/mobility/
#
# The data about the prices of fossil fuels:
# https://opendata.cbs.nl/statline/portal.html?_la=en&_catalog=CBS&tableId=80416ENG&_theme=1127
#
# Data about the traffic jams:
# https://downloads.rijkswaterstaatdata.nl/filedata/
#
# For the data from Google, some different places are shown. So makes google a difference between "Retail and recreation", "Supermarket and pharmacy", "Parks", "Public transport", "Workplaces" and "Residential". For "Retail and recreation", Google takes places such as restaurants, cafés, shopping centres, theme parks, museums, libraries and cinemas. For "Supermarket and pharmacy", Google will take places such as supermarkets, food warehouses, farmers markets, speciality food shops and pharmacies. For the "Parks", national parks, public beaches, marinas, dog parks, plazas and public gardens are taken together. The "Public transport" gets all the public transport hubs, such as underground, bus and train stations together. Mobility trends for places of work are summarized in workspaces and the residential will have all the mobility trends for places of residence.

# %% [markdown]
# ## Part I - Data import
#
# For holding the report clear, all the data import and processing of the data will be done in another notebook. The other notebook is deliverd in the github link.

# %% [markdown]
# ## Part II - Data visualisation
# To answer the research question, some subquestions are made for the visualization. Those four subquestions will be answered below. In part III the research question will be answered.

# %% [markdown]
# ### Q1: How did the costs of fossil fuels change during the year 2022?
# To answer the main research, it is needed to understand how fossil fuel prices change during the year. Also, it is good to understand what kind of events could have caused these changes.

# %%
# %store -r fig1
fig1.show()
# Out:
# <div>                            <div id="7fb4626c-2802-430d-a0aa-6fa08dde4d00" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7fb4626c-2802-430d-a0aa-6fa08dde4d00")) {                    Plotly.newPlot(                        "7fb4626c-2802-430d-a0aa-6fa08dde4d00",                        [{"customdata":[[20220101,"2022-01-01T00:00:00"],[20220102,"2022-01-02T00:00:00"],[20220103,"2022-01-03T00:00:00"],[20220104,"2022-01-04T00:00:00"],[20220105,"2022-01-05T00:00:00"],[20220106,"2022-01-06T00:00:00"],[20220107,"2022-01-07T00:00:00"],[20220108,"2022-01-08T00:00:00"],[20220109,"2022-01-09T00:00:00"],[20220110,"2022-01-10T00:00:00"],[20220111,"2022-01-11T00:00:00"],[20220112,"2022-01-12T00:00:00"],[20220113,"2022-01-13T00:00:00"],[20220114,"2022-01-14T0
# ...

# %% [markdown]
# ### Behavior of fossil fuels
#
#
#
# Fuel price movements in 2022 have been affected several times by politically significant moments. On 24 February, for instance, the war between Russia and Ukraine officially began. The price of Euro95 is currently still at €2.065 and diesel is at €1.753. Until 11 March, as a result, it will only continue to rise until Euro95 stands at €2.383 and diesel at €2.277. These are the highest prices for both Euro95 and diesel in Dutch history. From 11 March, prices stabilise and will also fall slightly. On 1 April, the price of fuel falls very sharply. This is due to a reduction in excise duty on fuel from the Dutch government. This new price of fuel will remain stable until 1 May, after which prices will rise again until mid-June. On the 11th of July, there was maintaince on the Nord Stream between Russia and Germany. However, this had no influence on the prices of Euro95 and Diesel. 7 August new sanctions package against Russia. European diesel is mainly sourced from Russia. These new sanctions, 2 weeks after implementation, cause the diesel price to be above the petrol price, where normally Euro95 is more expensive per litre than diesel. Petrol is mainly sourced from America, so this wasn't influenced by the sancions against Russia. From mid-June to the end of September, prices fell again, despite the problems with the Nord Stream pipelines. This involved maintenance and explosions.

# %% [markdown]
# ### Q2: How did the proportion of trips to different destinations change during the year 2022?

# %%
# %store -r fig2
fig2.show()
# Out:
# <div>                            <div id="7e2dc680-8bbf-4809-bb6e-4bb3888d8834" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7e2dc680-8bbf-4809-bb6e-4bb3888d8834")) {                    Plotly.newPlot(                        "7e2dc680-8bbf-4809-bb6e-4bb3888d8834",                        [{"hovertemplate":"variable=retail_and_recreation<br>date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"retail_and_recreation","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"retail_and_recreation","showlegend":true,"x":["2022-01-01","2022-01-02","2022-01-03","2022-01-04","2022-01-05","2022-01-06","2022-01-07","2022-01-08","2022-01-09","2022-01-10","2022-01-11","2022-01-12","2022-01-13","2022-01-14","2022-01-15","2
# ...

# %%
# %store -r fig4
fig4.show()
# Out:
# <div>                            <div id="af935709-62bd-4bcf-8b45-2c4cb61db979" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("af935709-62bd-4bcf-8b45-2c4cb61db979")) {                    Plotly.newPlot(                        "af935709-62bd-4bcf-8b45-2c4cb61db979",                        [{"alignmentgroup":"True","hovertemplate":"variable=Retail and reccreation<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Retail and reccreation","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Retail and reccreation","offsetgroup":"retail_and_recreation","orientation":"v","showlegend":true,"textposition":"auto","x":[0,1,2,3,4,5,6,7,8],"xaxis":"x","y":[-34.83870967741935,-15.142857142857142,-7.387096774193548,-0.8333333333333334,2.677419354
# ...

# %% [markdown]
# ### Mobility
#
# These figures above show the changes of mobility towards a baseline of 2020. The mobility is
# divided into different categories, each given a different color.
# As can be seen, in early 2022, transit stations are relatively more strongly negative in the
# beginning of the year than further into the year.
# In addition, it can be seen that the parks will rise from a value close to 0% very fast to over
# 150%. This could be partly explained by the weather picking up. As a result, more people are
# inclined to go to the park.
# Groceries and pharmacies are also rising. This could be because of the less strict COVID-19
# policy. From the month of May, the mobility does not change that much, which makes sense
# because doing groceries is a routine.
# Workplaces is also negative, but this number will become less negative during the year, with
# the exception of August. Here, it will fall harder once, before returning to its previous size in
# September.
# The mobility percentage to retail and recreation possibilities are rising the first three months
# to nearly 0%. After that it sits just above the baseline. The growth in the first three months
# could also be explained by the less strict COVID-19 policy.

# %% [markdown]
# ![sample_picture.jpg](fig5.png)

# %% [markdown]
# ### Transit stations compared to baseline
#
# As you can see in the figure showing the changes in movements involving transit stations compared to the baseline, there is an upward trend. This means more trips are being made by public transport. This could be related to the fact that the corona measures were abolished in March, but also to the greater fluctuations in fuel prices. In addition, a small dip can be seen in August. Due to the major holidays, this affects public transport movements. At the end, more people are travelling to transit stations during 2022.

# %% [markdown]
# ### Q3: How did the prices of fossil fuels influence the number of traffic jams?
# Classical theory often shows that the moment prices rise, demand for goods will decrease. Here, it is therefore interesting to see if an increase in prices of fossil fuels is followed by less travelling by car. When there are less cars on the road, it is expected to have less traffic jams. In the following figure, only the traffic jams caused by busy roads are shown.

# %%
# %store -r fig7
fig7.show()
# Out:
# <div>                            <div id="df0ec212-b911-49ca-833f-c933adbe8a7b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("df0ec212-b911-49ca-833f-c933adbe8a7b")) {                    Plotly.newPlot(                        "df0ec212-b911-49ca-833f-c933adbe8a7b",                        [{"alignmentgroup":"True","hovertemplate":"months=%{x}<br>total jam length [km]=%{text}<extra></extra>","legendgroup":"January","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"January","offsetgroup":"January","orientation":"v","showlegend":true,"text":[4216.0],"textposition":"auto","x":["January"],"xaxis":"x","y":[4216],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"months=%{x}<br>total jam length [km]=%{text}<extra></extra>","lege
# ...

# %% [markdown]
# ### Traffic jams
#
# Here the total length of traffic jams in kilometers is shown per month. The capacity of the roads is too small, that is the only reason for causing the traffic jams. Jams that are caused by accidents are not shown in the figure. In the first month of the year, the traffic has the smallest distance of traffic jams in the year 2022. In February and March, the traffic jams increase a lot. In the months of April and May, the jams are decreasing, followed by a big increase in the month of June. After that, there is a decrease in July and in August. In September there is a massive increase in the number of kilometers of traffic jams.
#
# ### Influence prices of fossil fuels on traffic jams
# The prices of fossil fuels will slightly increase in the months of January and February. This does not give the expected influence on the total amount of traffic jams. The total amount of traffic in jams even starts to grow. This is unexpected but can be explained. The increase in the amount of traffic in jams is caused by another factor. Due to less severe restrictions for COVID-19, people are allowed to work at their workplaces again. So more people will be on the road to travel from home to their workplaces. This causes more congestion.
# At the end of February, the war in Ukraine started and fuel prices went up. This does not immediately cause a decrease in the amount of traffic. The number of kilometres of traffic jams in March does even increase. This is probably still because the regulations on the COVID-19 situation are almost completely removed.
# In the month of April, the amount kilometres of traffic jams decreases. Now the rising prices of fossil fuels affect the number of traffic jams. It seems that the amount of traffic in jams decreases in the month after the prices of fossil fuels have increased. In the month of May, the traffic jams decrease even more. This means that there are fewer cars on the road. This is because people think it is too expensive to ride a car.
# In June the amount of traffic jams increases. This is odd because, in June, fuel prices are rising. It is expected that people would use fewer cars. A reason for the increase in traffic jams could be the protests of farmers. The farmers did not agree with the proposed nitrogen policy and decided to block some highways. This caused a lot of traffic jams.
# In the months of July and August, the traffic jams decrease again. This is expected because the prices of fossil fuels are still high. Even when there is a small decrease in the prices, the amount of traffic jams is about the same as in the month of April.
# In September the number of traffic jams grow a lot. This is not easily explained by the fossil fuel prices, but it could have another reason. The NS (Dutch Railway Company) has trouble with its employees. The employees organise strikes in the month of September. This could be an explanation for why the road gets busier than before. This causes more traffic jams in the month of September.

# %% [markdown]
# ### Q4: How strong is the correlation between the costs of fossil fuels and mobility behaviour?
# For this research, the correlation could be a conformation for the research question. The correlation is necessary for the validity of the project. In the figures below, the correlations between the prices of fossil fuels and travel destinies are shown.

# %% [markdown]
# ![sample_picture.jpg](fig6.png)

# %% [markdown]
# ### Heat map
#
# Looking at the heatmap several conclusions can be made about correlation between the costs of fossil fuels and mobility behavior. The movements involving retail and recreational purposes are positively low and moderately correlated with the Euro95 and Diesel prices, which means there are more movements registered with higher prices. This is the same for movements parks and to transit stations. Grocery and pharmacy movements only have a low positive correlation with the Diesel price. Movements between residential locations have a low and high negative correlation with Euro 95 and Diesel respectively, meaning that higher fuel prices cause less movements of this category. This shows that there is not much correlation in general for the movement categories excepts for the residential one. Also, the expected correlation would be the other way around for all the categories except the residential one, as higher fuel prices would make it more expensive to travel causing people to have less movements.

# %% [markdown]
# ## Part III - Conclusion

# %% [markdown]
# ### Answering the research question
#
#
# "How do the recent fluctuations of fossil fuel costs change the motives for travel of people in the Netherlands in 2022?"

# %% [markdown]
# To give an answer to the research question, the anwers of the subquestions are necessary. These answers are given in the parts above. Here the needed answers are shortly described again.
#
# Prices of fossil fuels behave most of the time like what was expected, except for the nordstream situation. Due to the war in Ukraine and the stop on gas delivery by Russia, the prices of fossil fuels have risen. This is a reason for one big fluctuation of the prices of fossil fuels. Also the fuel tax reduction created a big decrease of the price.
#
#
# It was expected that the prices of fossil fuels would have an influence on the mobility of people in the Netherlands. When the prices of fossil fuels would increase, the mobility was expected to decrease. This relation cannot be seen. When figure 1 and figure 4 are shown above eachother, the extreme values don't have a reaction on each other. Furthermore, when figure 1 and figure 7 are considered, the number of traffic jams also does not react on the prices of fossil fuels. When the prices of fossil fuels would increase, it would be expected that the number of traffic jams would decrease due to less people attending the road.
#
# Also, when looking at the heatmap, it is shown that there is not a strong correlation between the prices of fossil fuels and the amount of undertaken trips to different destinations. This is another indication that the recent fluctuations of fossil fuel costs does not change the motives for travel of people in the Netherlands in 2022.
#
# So to give an answer to the research question, the recent fluctuations of the fossil fuel costs do not change the motives for travel of people in the Netherlands.
#
# An explanation for this could be that the people are not influenced by the rising prices of fossil fuels when considering their motive to travel. The people in the Netherlands could be so used to using their car to a destination that the risen prices won't have an effect on their travel behavior. Maybe when the prices are getting even higher or when the prices stay high for a longer period of time, people would consider not to make trips to certain destinations.
# Also, when is considered that the COIVD-19 pandemic of the previous 2 years has finally ended, people are not willing to lose  mobility. People are finally able to travel again and won't let the fossil fuel costs change their travel behavior.
#
# ### Discussion
# For this research to come to a better conclusion in the future, it might be useful to look at the following things. For starters, it would be useful to break down the correlations between different purposes and petrol prices more, to increase the strength of the correlations. Furthermore, corona relaxations could also be included in the report, in order to exclude those influences on the final answer.
# In addition, it would add value to the study if traffic jams were shown on a small time scale. Now it was only possible to look at it per month, but per day or week would already save a lot here.
